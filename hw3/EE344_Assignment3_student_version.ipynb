# %% [markdown]
# # EE 344 — Assignment 3: Walmart Weekly Sales Regression
#
# In this assignment, you will predict **Weekly_Sales** using tabular store/economic features.
#
# To keep things focused, you will do **only one preprocessing mode**:
#
# - **scale_all_after_ohe**: one-hot encode categorical features, then standardize *all* resulting features.
#
# Then you will train and evaluate **four models** using **fixed hyperparameters** (no grid search):
# - Elastic Net
# - K-Nearest Neighbors (KNN)
# - Decision Tree (DT)
# - Random Forest (RF)
#
# ---
#
# ## Submission guidelines
# - Complete all **[TODO]** blocks in this notebook.
# - Push the finished notebook to your **GitHub repository**.
# - Submit the **GitHub link** on the Canvas submission page.

# %% [markdown]
# ## Setup
#
# Run the next cell to import libraries and define helper functions.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import ElasticNet, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import StackingRegressor


from sklearn.metrics import root_mean_squared_error, mean_absolute_error, mean_squared_error, r2_score

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def evaluate_regression(model, X_train, X_test, y_train, y_test):
    """Fit on train, evaluate on test."""
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    return {
        "MAE": mean_absolute_error(y_test, pred),
        "RMSE": rmse(y_test, pred),
        "R2": r2_score(y_test, pred),
    }

# Reproducibility
RANDOM_STATE = 42

# %% [markdown]
# ## Load data
#
# - Put the dataset CSV in the **same folder** as this notebook (recommended), or provide an absolute path.
# - We drop the **Date** column (if present).
# - We treat **Store** and **Holiday_Flag** as categorical.

# %%
# === Data path ===
# If your CSV file has a different name/path, update it here.
DATA_PATH = "Walmart_Store_sales.csv"

# Load
df = pd.read_csv(DATA_PATH)

# Drop Date (if present)
if "Date" in df.columns:
    df = df.drop(columns=["Date"])

# Target and features
y = df["Weekly_Sales"]
X = df.drop(columns=["Weekly_Sales"])

# Treat these as categorical (even if stored as ints)
for col in ["Store", "Holiday_Flag"]:
    if col in X.columns:
        X[col] = X[col].astype(str)

display(df.head())
print("Shape:", df.shape)
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# 4         8.106
# Shape: (6435, 7)

# %% [markdown]
# ## Train/test split
#
# We keep a standard **80/20 random split**.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=RANDOM_STATE
)

print("Train:", X_train.shape, "Test:", X_test.shape)
# Out:
# Train: (5148, 6) Test: (1287, 6)

# %% [markdown]
# ## Preprocessing: scale_all_after_ohe
#
# Goal:
# 1) One-hot encode categorical columns (so everything becomes numeric)
# 2) Standardize **all** resulting features
#
# You will build a preprocessing pipeline that you can reuse for all four models.

# %%
# --- Identify categorical and numeric columns ---
# We will treat Store and Holiday_Flag as categorical.
# All other columns are numeric (for this dataset).

## [ TODO ]
# 1) Create a list `cat_cols` that includes the categorical columns present in X
# 2) Create a list `num_cols` that includes all remaining columns in X (numeric)
#    Hint: You can do this programmatically using X.columns
cat_cols = ["Store", "Holiday_Flag"]
num_cols = X.columns.difference(cat_cols)

print("Categorical columns:", cat_cols)
print("Numeric columns:", num_cols)

# --- Build scale_all_after_ohe preprocessing pipeline ---
ohe = OneHotEncoder(handle_unknown="ignore")

## [ TODO ]
# Create a ColumnTransformer that:
# - applies One-hot encoding (OHE) to cat_cols
# - passes through num_cols unchanged
# Then apply StandardScaler(with_mean=False) to scale all features.
#
# Name the final pipeline variable: `prep_A`
#
# Hint: ColumnTransformer(..., remainder="drop")
# Hint: StandardScaler(with_mean=False) is sparse-friendly.

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", ohe, cat_cols),
        ("num", "passthrough", num_cols),
    ],
    remainder="drop"
)

prep_A = Pipeline(
    steps=[
        ("preprocess", preprocessor),
        ("scale", StandardScaler(with_mean=False)),
    ]
)

PREP_MODES = {
    "scale_all_after_ohe": prep_A
}

prep_A
# Out:
# Categorical columns: ['Store', 'Holiday_Flag']
# Numeric columns: Index(['CPI', 'Fuel_Price', 'Temperature', 'Unemployment'], dtype='object')
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Store', 'Holiday_Flag']),
#                                                  ('num', 'passthrough',
#                                                   Index(['CPI', 'Fuel_Price', 'Temperature', 'Unemployment'], dtype='object'))])),
#                 ('scale', StandardScaler(with_mean=False))])

# %% [markdown]
# ## Implementation of Regression Models
#
# Create 4 pipelines, each with:
# - `("prep", prep_A)`
# - `("model", <your model with fixed params>)`
#
# **Use the exact parameters below:**
# - RandomForestRegressor: `n_estimators=200`, `max_depth=None`, `max_features="sqrt"`, `min_samples_leaf=1`
# - KNeighborsRegressor: `n_neighbors=15`, `weights="distance"`
# - ElasticNet: `alpha=0.001`, `l1_ratio=0.9`
# - DecisionTreeRegressor: `max_depth=None`, `min_samples_leaf=10`

# %%
## [ TODO ]
# Build the 4 pipelines below.
#
# Notes:
# - For ElasticNet, it can help to raise max_iter to avoid convergence warnings.
# - For DT/RF, set random_state=RANDOM_STATE for reproducibility.

rf_pipe = Pipeline([
    ("prep", prep_A),
    ("model", RandomForestRegressor(n_estimators=200, max_depth=None, max_features="sqrt", min_samples_leaf=1,
                                    random_state = RANDOM_STATE))
])

knn_pipe = Pipeline([
    ("prep", prep_A),
    ("model", KNeighborsRegressor(n_neighbors=15, weights="distance"))
])

enet_pipe = Pipeline([
    ("prep", prep_A),
    ("model", ElasticNet(alpha=0.001, l1_ratio=0.9, max_iter=10000, random_state=RANDOM_STATE))
])

dt_pipe = Pipeline([
    ("prep", prep_A),
    ("model", DecisionTreeRegressor(max_depth=None, min_samples_leaf=10, random_state=RANDOM_STATE))
])

MODELS = {
    "RandomForest": rf_pipe,
    "KNN": knn_pipe,
    "ElasticNet": enet_pipe,
    "DecisionTree": dt_pipe,
}

MODELS
# Out:
# {'RandomForest': Pipeline(steps=[('prep',
#                   Pipeline(steps=[('preprocess',
#                                    ColumnTransformer(transformers=[('cat',
#                                                                     OneHotEncoder(handle_unknown='ignore'),
#                                                                     ['Store',
#                                                                      'Holiday_Flag']),
#                                                                    ('num',
#                                                                     'passthrough',
#                                                                     Index(['CPI', 'Fuel_Price', 'Temperature', 'Unemployment'], dtype='object'))])),
#                                   ('scale', StandardScaler(with_mean=False))])),
#                  ('model',
#                   RandomForestRegressor(max_features='sqrt', n_estimators=200,
#                                         random_state=42))]),
#  'KNN': Pipeline(steps=[('prep',
#                   Pipeline(steps=[('preprocess',
#                                    ColumnTransformer(transformers=[('cat',
#                                                                     OneHotEncoder(handle_unknown='ignore'),
#                                                                     ['Store',
#                                                                      'Holiday_Flag']),
#                                                                    ('num',
#                                                                     'passthrough',
#                                                                     Index(['CPI', 'Fuel_Price', 'Temperature', 'Unemployment'], dtype='object'))])),
#                                   ('scale', StandardScaler(with_mean=False))])),
#                  ('model',
#                   KNeighborsRegressor(n_neighbors=15, weights='distance'))]),
#  'ElasticNet': Pipeline(steps=[('prep',
#                   Pipeline(steps=[('preprocess',
#                                    ColumnTransformer(transformers=[('cat',
#                                                                     OneHotEncoder(handle_unknown='ignore'),
#                                                                     ['Store',
#                                                                      'Holiday_Flag']),
#                                                                    ('num',
#                                                                     'passthrough',
#                                                                     Index(['CPI', 'Fuel_Price', 'Temperature', 'Unemployment'], dtype='object'))])),
#                                   ('scale', StandardScaler(with_mean=False))])),
#                  ('model',
#                   ElasticNet(alpha=0.001, l1_ratio=0.9, max_iter=10000,
#                              random_state=42))]),
#  'DecisionTree': Pipeline(steps=[('prep',
#                   Pipeline(steps=[('preprocess',
#                                    ColumnTransformer(transformers=[('cat',
#                                                                     OneHotEncoder(handle_unknown='ignore'),
#                                                                     ['Store',
#                                                                      'Holiday_Flag']),
#                                                                    ('num',
#                                                                     'passthrough',
#                                                                     Index(['CPI', 'Fuel_Price', 'Temperature', 'Unemployment'], dtype='object'))])),
#                                   ('scale', StandardScaler(with_mean=False))])),
#                  ('model',
#                   DecisionTreeRegressor(min_samples_leaf=10, random_state=42))])}

# %% [markdown]
# ## Evaluation (CV RMSE + test metrics)
#
# Following code block computes:
# - **5-fold CV RMSE** on the *training set* (for a fair comparison)
# - **test MAE / RMSE / R²** after fitting on the full training set

# %%
# 5-fold CV (shuffle for reproducibility)
cv = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

rows = []

for name, pipe in MODELS.items():
    # --- CV RMSE ---
    # cross_val_score returns NEGATIVE values when using neg_root_mean_squared_error.
    cv_scores = cross_val_score(
        pipe,
        X_train, y_train,
        scoring="neg_root_mean_squared_error",
        cv=cv,
        n_jobs=1
    )
    cv_rmse = -cv_scores.mean()

    # --- Test metrics ---
    metrics = evaluate_regression(pipe, X_train, X_test, y_train, y_test)

    rows.append({
        "Preprocess": "scale_all_after_ohe",
        "Model": name,
        "Best CV RMSE": cv_rmse,
        "MAE": metrics["MAE"],
        "RMSE": metrics["RMSE"],
        "R2": metrics["R2"],
    })

results_df = pd.DataFrame(rows).sort_values("RMSE").reset_index(drop=True)
display(results_df)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52083387787117.84, tolerance: 131770976217.2606
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51172290013127.766, tolerance: 131323286376.3119
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53942944837171.375, tolerance: 129981253904.32805
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51832537713700.92, tolerance: 130806128744.70816
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 52303768177435.64, tolerance: 129936350603.35078
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65482949540203.16, tolerance: 163457864416.10596
#   model = cd_fast.sparse_enet_coordinate_descent(
#             Preprocess         Model   Best CV RMSE           MAE  \
# 0  scale_all_after_ohe  RandomForest  142874.601917  71808.779611
# 1  scale_all_after_ohe           KNN  152200.243436  77729.980038
# 2  scale_all_after_ohe    ElasticNet  161200.006816  91010.553483
# 3  scale_all_after_ohe  DecisionTree  160736.325291  89121.647239
#
#             RMSE        R2
# 0  138511.449636  0.940447
# 1  145549.240578  0.934241
# 2  159673.210895  0.920859
# 3  164051.014771  0.916460

# %% [markdown]
# ## Model Stacking (Decision Tree + Elastic Net)
#
# A single model might miss patterns that another model captures well.
# - **Decision Tree** can learn nonlinear splits and feature interactions.
# - **Elastic Net** is a strong regularized linear model.
#
# **Stacking** trains multiple base models, then trains a final model (a *meta-learner*) on their predictions.
# Here we stack:
# - base models: **Decision Tree + Elastic Net**
# - meta-learner: **Ridge regression**
#
# We use `cv=5` so the meta-learner is trained on out-of-fold predictions (more realistic and less leakage).

# %%
# --- Stacking (DT + ElasticNet) ---

prep = PREP_MODES["scale_all_after_ohe"]

## [ TODO ]
# 1) Create `enet_best` as a Pipeline:
#    ("prep", prep) -> ("model", ElasticNet(alpha=0.001, l1_ratio=0.5, random_state=42, max_iter=10000))
#
# 2) Create `dt_best` as a Pipeline:
#    ("prep", prep) -> ("model", DecisionTreeRegressor(max_depth=None, min_samples_leaf=10, random_state=42))
#
# 3) Create `stack` as a StackingRegressor:
#    estimators=[("dt", dt_best), ("enet", enet_best)]
#    final_estimator=Ridge(alpha=0.9)
#    cv=5
#    n_jobs=1

enet_best = Pipeline([
    ("prep", prep),
    ("model", ElasticNet(alpha=0.001, l1_ratio=0.5, random_state=42, max_iter=10000))
])

dt_best = Pipeline([
    ("prep", prep),
    ("model", DecisionTreeRegressor(max_depth=None, min_samples_leaf=10, random_state=42))
])

stack = StackingRegressor(
    estimators=[("dt", dt_best), ("enet", enet_best)],
    final_estimator=Ridge(alpha=0.9),
    cv=5,
    n_jobs=1
)

#raise NotImplementedError("Complete the stacking TODOs above.")

## [ TODO ]
# 4) Fit on (X_train, y_train), then predict on test.
# 5) Print MAE, RSME, R^2, metrics for the X_test.

stack.fit(X_train, y_train)
y_pred = stack.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Stacking Regressor Performance:")
print(f"MAE:  {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R²:   {r2:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27886474145288.28, tolerance: 163457864416.10596
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22300265408406.42, tolerance: 131523352296.64708
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23128216580532.953, tolerance: 132434725424.95358
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22365338114005.66, tolerance: 129343635688.60757
#   model = cd_fast.sparse_enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20917743505741.18, tolerance: 131172568200.89124
#   model = cd_fast.sparse_enet_coordinate_descent(
# Stacking Regressor Performance:
# MAE:  83751.0727
# RMSE: 154562.2430
# R²:   0.9258
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22561338713180.062, tolerance: 129350475039.0364
#   model = cd_fast.sparse_enet_coordinate_descent(
